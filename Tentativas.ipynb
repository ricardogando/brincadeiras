# %% [markdown]
# http://delas.ig.com.br/filhos/brincadeiras/par-ou-impar/4e42ea7c5cf358183f000023.html

# %%
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd

# %%
amigos = np.arange(1,3)
numero_interacoes = 50
casa = np.random.randint(0,6)

# %%
for cada in amigos:
    par = 0
    impar = 0
    for interacao in xrange(numero_interacoes):
        parouimpar = np.random.randint(6, size=amigos)
        parouimpar.tofile('poi.txt')
        #np.savetxt('poi.txt', parouimpar, fmt="%.2f", delimiter=',')
        print parouimpar
        a = np.sum(parouimpar)
        if a%2 == 0:
            par = par+1
        else:
            impar = impar + 1
        
#np.savetxt('poi.txt', parouimpar, fmt="%.1f", delimiter=',')
# Out:
# [[2 5]]
# [[3 0]]
# [[3 3]]
# [[5 4]]
# [[4 0]]
# [[1 2]]
# [[1 4]]
# [[2 1]]
# [[4 3]]
# [[5 4]]
# [[4 5]]
# [[3 4]]
# [[2 2]]
# [[5 3]]
# [[3 1]]
# [[4 4]]
# [[5 5]]
# [[1 5]]
# [[3 3]]
# [[2 1]]
# [[1 3]]
# [[1 0]]
# [[3 4]]
# [[4 0]]
# [[2 1]]
# [[0 0]]
# [[0 4]]
# [[4 1]]
# [[3 4]]
# [[1 5]]
# [[5 3]]
# [[1 2]]
# [[5 2]]
# [[4 4]]
# [[5 3]]
# [[0 5]]
# [[1 3]]
# [[2 4]]
# [[3 4]]
# [[0 2]]
# [[5 4]]
# [[5 5]]
# [[1 2]]
# [[1 1]]
# [[2 3]]
# [[5 4]]
# [[5 3]]
# [[3 3]]
# [[0 5]]
# [[0 0]]
# [[3 3]]
# [[5 3]]
# [[4 1]]
# [[5 5]]
# [[3 1]]
# [[5 4]]
# [[3 4]]
# [[0 0]]
# [[2 4]]
# [[2 4]]
# [[2 0]]
# [[0 2]]
# [[3 3]]
# [[3 1]]
# [[4 5]]
# [[2 4]]
# [[5 3]]
# [[5 2]]
# [[5 5]]
# [[5 1]]
# [[0 5]]
# [[0 0]]
# [[1 5]]
# [[5 4]]
# [[5 4]]
# [[2 3]]
# [[3 2]]
# [[3 0]]
# [[4 2]]
# [[4 4]]
# [[2 3]]
# [[3 2]]
# [[2 4]]
# [[3 3]]
# [[3 5]]
# [[3 5]]
# [[2 3]]
# [[3 2]]
# [[2 0]]
# [[2 2]]
# [[0 4]]
# [[5 1]]
# [[1 4]]
# [[5 2]]
# [[3 5]]
# [[3 4]]
# [[2 1]]
# [[4 3]]
# [[3 2]]
# [[2 1]]

# %%
parouimpar.tofile?

# %%
np.savetxt('poi.txt', parouimpar, fmt="%.1f", delimiter=',')
print par , impar
# Out:
# 28 22

# %%
import seaborn as sns

import pylab

pylab.plot(poi[:,0], poi[:,1])

# %%
from scipy.stats import kendalltau
sns.set(style="ticks")

#rs = parouimpar
x = parouimpar(size=1000)
y = a(size=1000)

sns.jointplot(x, y, kind="hex", stat_func=kendalltau, color="blue")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-0e0cec35d2ec> in <module>()
#       3
#       4 #rs = parouimpar
# ----> 5 x = parouimpar(size=1000)
#       6 y = a(size=1000)
#       7
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
parouimpar1 = np.random.randint(6, size=(50,2))
print parouimpar1
a = np.sum(parouimpar1, axis=1)
print a
# Out:
# [[1 0]
#  [3 2]
#  [2 1]
#  [5 4]
#  [5 1]
#  [3 3]
#  [4 5]
#  [3 3]
#  [5 4]
#  [5 2]
#  [2 4]
#  [4 4]
#  [5 3]
#  [5 1]
#  [3 4]
#  [4 0]
#  [0 1]
#  [3 2]
#  [0 5]
#  [2 5]
#  [1 2]
#  [5 0]
#  [5 3]
#  [5 5]
#  [3 3]
#  [4 3]
#  [2 4]
#  [2 5]
#  [1 1]
#  [4 2]
#  [3 5]
#  [0 3]
#  [2 0]
#  [2 3]
#  [2 5]
#  [3 5]
#  [0 1]
#  [0 3]
#  [5 4]
#  [5 4]
#  [0 5]
#  [1 3]
#  [0 2]
#  [1 2]
#  [5 1]
#  [0 3]
#  [0 4]
#  [2 2]
#  [1 2]
#  [1 0]]
# [ 1  5  3  9  6  6  9  6  9  7  6  8  8  6  7  4  1  5  5  7  3  5  8 10  6
#   7  6  7  2  6  8  3  2  5  7  8  1  3  9  9  5  4  2  3  6  3  4  4  3  1]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-878b09165526> in <module>()
#       5 a = np.sum(parouimpar1, axis=1)
#       6 print a
# ----> 7 if a%2 == 0:
#       8     par = par+1
#       9 else:
#
# ...

# %%
poi = pd.DataFrame(parouimpar1, index=range(1,51), columns=['Jogador 1: par', 'Jogador 2: impar'])
poi
# Out:
#     Jogador 1: par  Jogador 2: impar
# 1                1                 0
# 2                3                 2
# 3                2                 1
# 4                5                 4
# 5                5                 1
# 6                3                 3
# 7                4                 5
# 8                3                 3
# 9                5                 4
# 10               5                 2
# 11               2                 4
# 12               4                 4
# 13               5                 3
# 14               5                 1
# 15               3                 4
# 16               4                 0
# 17               0                 1
# 18               3                 2
# 19               0                 5
# 20               2                 5
# 21               1                 2
# 22               5                 0
# 23               5                 3
# 24               5                 5
# ...

# %%
poi ['Soma']= poi.sum(axis=1)

# %%
poi
# Out:
#     Jogador 1: par  Jogador 2: impar  Soma
# 1                1                 0     1
# 2                3                 2     5
# 3                2                 1     3
# 4                5                 4     9
# 5                5                 1     6
# 6                3                 3     6
# 7                4                 5     9
# 8                3                 3     6
# 9                5                 4     9
# 10               5                 2     7
# 11               2                 4     6
# 12               4                 4     8
# 13               5                 3     8
# 14               5                 1     6
# 15               3                 4     7
# 16               4                 0     4
# 17               0                 1     1
# 18               3                 2     5
# 19               0                 5     5
# 20               2                 5     7
# 21               1                 2     3
# ...

# %%
poi['Resultado'] = np.where(poi['Soma']%2==0, 'Par', 'Impar')

# %%
poi
# Out:
#     Jogador 1: par  Jogador 2: impar  Soma Resultado
# 1                1                 0     1     Impar
# 2                3                 2     5     Impar
# 3                2                 1     3     Impar
# 4                5                 4     9     Impar
# 5                5                 1     6       Par
# 6                3                 3     6       Par
# 7                4                 5     9     Impar
# 8                3                 3     6       Par
# 9                5                 4     9     Impar
# 10               5                 2     7     Impar
# 11               2                 4     6       Par
# 12               4                 4     8       Par
# 13               5                 3     8       Par
# 14               5                 1     6       Par
# 15               3                 4     7     Impar
# 16               4                 0     4       Par
# 17               0                 1     1     Impar
# ...

# %%
Impar = poi.Resultado.str.contains(r'[Im]').sum()
Par = 50 - Impar
if Par > Impar:
    print 'O Jogador 1 Ganhou!'
else:
    print 'O JOgador 2 Ganhou!'
# Out:
# O JOgador 2 Ganhou!
